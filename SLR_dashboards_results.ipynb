# %%
# -*- coding: utf-8 -*-
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 20)


import numpy as np

from scipy import stats


from bokeh.io import show, output_file, export_png
from bokeh.plotting import figure

 
# use creds to create a client to interact with the Google Drive API



scope = ['https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name('client.json', scope)
client = gspread.authorize(creds)

from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.transform import factor_cmap
from bokeh.palettes import Category20b
from bokeh.models import LabelSet
import math

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="93480">Loading BokehJS ...</span>
#     </div>

# %%
print("The following sheets are available")
for sheet in client.openall():
    print("{} - {}".format(sheet.title, sheet.id))


spreadsheet = client.open_by_key("1Dt2M32K0WDfhLCAadtp1uEVW0fLG5htNu_G2tK_OQdU")
sheetFinalResults = spreadsheet.get_worksheet(4)
# Out:
# The following sheets are available
# SLR - 1Dt2M32K0WDfhLCAadtp1uEVW0fLG5htNu_G2tK_OQdU

# %%
df = pd.DataFrame(sheetFinalResults.get_all_records())

# %%
df.head()
# Out:
#          Application domain  \
# 0         Energy monitoring
# 1  Microservices monitoring
# 2      Emergency management
# 3                        BI
# 4       Services monitoring
#
#                                              Authors  \
# 0       Filonik D.;Medland R.;Foth M.;Rittenbruch M.
# 1                              Mayer B.;Weinreich R.
# 2   Nascimento B. S.; Vivacqua A. S.;Borges M. R. S.
# 3  Noonpakdee W.;Khunkornsiri T.;Phothichai A.;Da...
# 4                        Kumar K.;Bose J.;Soni S. K.
#
#                           Conference or journal name  \
# 0  Lecture Notes in Computer Science (including s...
# 1  2017 IEEE International Conference on Software...
# 2  2016 IEEE International Conference on Systems,...
# 3  2018 5th International Conference on Industria...
# 4  2017 14th IEEE India Council International Con...
#
#                             DOI  \
# 0   10.1007/978-3-642-37157-8_8
# 1         10.1109/ICSAW.2017.44
# 2      10.1109/SMC.2016.7844746
# 3      10.1109/IEA.2018.8387148
# 4  10.1109/INDICON.2017.8487236
#
#                           Detailed classification  \
# 0                      Customizable (user-driven)
# 1                      Customizable (user-driven)
# 2                          Assisted customization
# 3  Customizable (designer-driven and user-driven)
# 4                      Customizable (user-driven)
#
#        First level classification  \
# 0                    Customizable
# 1                    Customizable
# 2  Customizable w/ system support
# 3                    Customizable
# 4                    Customizable
#
#   Generative approach? (applicable to those solutions that need a pre-configuration)  \
# 0                                                 NA
# 1                                                 NA
# 2                                                 NA
# 3                                            Partial
# 4                                                 NA
#
#                                             Keywords  \
# 0  energy monitoring;environmental sustainability...
# 1  Microservices;microservice monitoring;microser...
# 2  Emergency management;information visualization...
# 3  Dashboard design;Bussiness Intelligence;Small ...
# 4  Data analytics;Mobile applications analytics;s...
#
#                                  Method  \
# 0                  Configuration wizard
# 1                  Configuration wizard
# 2  Configuration wizard, visual mapping
# 3                 Pre-defined templates
# 4                   Configuration files
#
#                         Source (name of publication)  \
# 0  Lecture Notes in Computer Science (including s...
# 1  2017 IEEE International Conference on Software...
# 2  2016 IEEE International Conference on Systems,...
# 3  2018 5th International Conference on Industria...
# 4  2017 14th IEEE India Council International Con...
#
#   Stage at which the variation / customization / personalization is performed  \
# 0                                 User-configuration
# 1                                 User-configuration
# 2                                 User-configuration
# 3                                  Pre-configuration
# 4                                 User-configuration
#
#   Support provided by a software solution?  \
# 0                                      Yes
# 1                                      Yes
# 2                                      Yes
# 3                                      Yes
# 4                                      Yes
#
#             Target of the variability process Tested in real-world scenario?  \
# 0  Displayed data, visualization type, layout                            Yes
# 1  Displayed data, visualization type, layout                             No
# 2  Displayed data, visualization type, layout                            Yes
# 3  Displayed data, visualization type, layout                            Yes
# 4  Displayed data, visualization type, layout                             No
#
#   The solution outcome is a fully functional dashboard?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#                                                Title  \
# 0  A customisable dashboard display for environme...
# 1  A Dashboard for Microservice Monitoring and Ma...
# 2  A flexible architecture for selection and visu...
# 3  A framework for analyzing and developing dashb...
# 4  A Generic Visualization Framework based on a D...
#
#   Type of publication (Journal, Book, Conference proceedings, etc)  \
# 0                                   Conference Paper
# 1                                   Conference Paper
# 2                                   Conference Paper
# 3                                   Conference Paper
# 4                                   Conference Paper
#
#   Variability factors (factors that affect the dashboard composition)  Year
# 0                                   User preferences                   2013
# 1                                   User preferences                   2017
# 2                                   User preferences                   2016
# 3                       User preferences, guidelines                   2018
# 4                                   User preferences                   2017

# %%
print("Number of papers resulting the SLR: ", len(df))
# Out:
# Number of papers resulting the SLR:  25

# %%
keywords = df["Keywords"].dropna().astype('str').values
keywords_list = []
for keyword in keywords:
    [keywords_list.append(x.strip().lower()) for x in keyword.split(';')]
    
keywords_list = [x for x in keywords_list if x != '']
dfKeywords = pd.DataFrame(keywords_list)

# %%
dfKeywords
# Out:
#                                              0
# 0                            energy monitoring
# 1                 environmental sustainability
# 2                        persuasive technology
# 3                        domestic environments
# 4                                   households
# 5                            urban informatics
# 6                                microservices
# 7                      microservice monitoring
# 8                      microservice management
# 9                       microservice dashboard
# 10                        emergency management
# 11                   information visualization
# 12                                   dashboard
# 13                               collaboration
# 14                            dashboard design
# 15                      bussiness intelligence
# 16                 small and medium enterprise
# 17                                         sme
# 18                              data analytics
# 19               mobile applications analytics
# 20                          services analytics
# 21                                 data driven
# 22                          data visualization
# 23                         analytics dashboard
# 24                          data visualization
# 25                         multi-agent systems
# 26               on-line analytical processing
# 27                             usage profiling
# 28                         adaptive dashboards
# 29                                        jade
# 30                                  dashboards
# 31                          business processes
# 32                                  monitoring
# 33                                 controlling
# 34                                         xml
# 35                           system monitoring
# 36                       operations monitoring
# 37                        real-time monitoring
# 38                         web-based dashboard
# 39                            mobile dashboard
# 40                          business processes
# 41                                  monitoring
# 42                                  dashboards
# 43                                       roles
# 44                                       views
# 45                    model-driven development
# 46                          internet of things
# 47                                device cloud
# 48                       remote user interface
# 49                            device dashboard
# 50                                      tr-069
# 51                                    web apis
# 52                         semantic annotation
# 53                     monitoring environments
# 54       dynamic composition and visualization
# 55                                  dashboards
# 56                          synchronized views
# 57                     interface customization
# 58                                novice users
# 59                              visual queries
# 60            business intelligence dashboards
# 61                                  aesthetics
# 62                                   dashboard
# 63                                   generator
# 64                        usability guidelines
# 65                                user testing
# 66                    model-driven development
# 67                                   dashboard
# 68             business performance management
# 69  interactive data exploration and discovery
# 70                          data visualization
# 71                            data exploration
# 72                   graphical user interfaces
# 73                                 interaction
# 74                                      design
# 75                        user-centered design
# 76                               visualization
# 77                            user interaction
# 78               on-line analytical processing
# 79                 adaptive dashboards systems
# 80                        olap personalization
# 81                         private data clouds
# 82                         multi-agent systems
# 83                                 variability
# 84                          data visualisation
# 85                                     sensors
# 86                           model composition
# 87                 learning analytic dashboard
# 88                         dashboard generator
# 89                             dashboard model
# 90                                user’s needs
# 91                                     context

# %%
dfKeywords.columns = ['Term']

# %%
resultsKeywords = pd.DataFrame(dfKeywords['Term'].value_counts())
resultsKeywords
# Out:
#                                             Term
# data visualization                             3
# dashboards                                     3
# dashboard                                      3
# monitoring                                     2
# multi-agent systems                            2
# business processes                             2
# model-driven development                       2
# on-line analytical processing                  2
# internet of things                             1
# olap personalization                           1
# operations monitoring                          1
# graphical user interfaces                      1
# model composition                              1
# microservice monitoring                        1
# learning analytic dashboard                    1
# persuasive technology                          1
# system monitoring                              1
# dashboard design                               1
# views                                          1
# dashboard model                                1
# device dashboard                               1
# xml                                            1
# mobile dashboard                               1
# user interaction                               1
# visualization                                  1
# dynamic composition and visualization          1
# novice users                                   1
# microservice management                        1
# data driven                                    1
# synchronized views                             1
# jade                                           1
# context                                        1
# analytics dashboard                            1
# controlling                                    1
# aesthetics                                     1
# device cloud                                   1
# usability guidelines                           1
# data analytics                                 1
# data visualisation                             1
# mobile applications analytics                  1
# web apis                                       1
# environmental sustainability                   1
# business performance management                1
# emergency management                           1
# collaboration                                  1
# households                                     1
# sme                                            1
# generator                                      1
# real-time monitoring                           1
# information visualization                      1
# remote user interface                          1
# interaction                                    1
# roles                                          1
# dashboard generator                            1
# services analytics                             1
# tr-069                                         1
# adaptive dashboards systems                    1
# semantic annotation                            1
# interface customization                        1
# variability                                    1
# user-centered design                           1
# private data clouds                            1
# web-based dashboard                            1
# interactive data exploration and discovery     1
# microservice dashboard                         1
# small and medium enterprise                    1
# domestic environments                          1
# business intelligence dashboards               1
# urban informatics                              1
# monitoring environments                        1
# energy monitoring                              1
# visual queries                                 1
# bussiness intelligence                         1
# microservices                                  1
# usage profiling                                1
# data exploration                               1
# user testing                                   1
# user’s needs                                   1
# design                                         1
# adaptive dashboards                            1
# sensors                                        1

# %%
resultsKeywords.reset_index(inplace=True)
resultsKeywords.columns = ['Term', 'Count']

resultsKeywords
# Out:
#                                           Term  Count
# 0                           data visualization      3
# 1                                   dashboards      3
# 2                                    dashboard      3
# 3                                   monitoring      2
# 4                          multi-agent systems      2
# 5                           business processes      2
# 6                     model-driven development      2
# 7                on-line analytical processing      2
# 8                           internet of things      1
# 9                         olap personalization      1
# 10                       operations monitoring      1
# 11                   graphical user interfaces      1
# 12                           model composition      1
# 13                     microservice monitoring      1
# 14                 learning analytic dashboard      1
# 15                       persuasive technology      1
# 16                           system monitoring      1
# 17                            dashboard design      1
# 18                                       views      1
# 19                             dashboard model      1
# 20                            device dashboard      1
# 21                                         xml      1
# 22                            mobile dashboard      1
# 23                            user interaction      1
# 24                               visualization      1
# 25       dynamic composition and visualization      1
# 26                                novice users      1
# 27                     microservice management      1
# 28                                 data driven      1
# 29                          synchronized views      1
# 30                                        jade      1
# 31                                     context      1
# 32                         analytics dashboard      1
# 33                                 controlling      1
# 34                                  aesthetics      1
# 35                                device cloud      1
# 36                        usability guidelines      1
# 37                              data analytics      1
# 38                          data visualisation      1
# 39               mobile applications analytics      1
# 40                                    web apis      1
# 41                environmental sustainability      1
# 42             business performance management      1
# 43                        emergency management      1
# 44                               collaboration      1
# 45                                  households      1
# 46                                         sme      1
# 47                                   generator      1
# 48                        real-time monitoring      1
# 49                   information visualization      1
# 50                       remote user interface      1
# 51                                 interaction      1
# 52                                       roles      1
# 53                         dashboard generator      1
# 54                          services analytics      1
# 55                                      tr-069      1
# 56                 adaptive dashboards systems      1
# 57                         semantic annotation      1
# 58                     interface customization      1
# 59                                 variability      1
# 60                        user-centered design      1
# 61                         private data clouds      1
# 62                         web-based dashboard      1
# 63  interactive data exploration and discovery      1
# 64                      microservice dashboard      1
# 65                 small and medium enterprise      1
# 66                       domestic environments      1
# 67            business intelligence dashboards      1
# 68                           urban informatics      1
# 69                     monitoring environments      1
# 70                           energy monitoring      1
# 71                              visual queries      1
# 72                      bussiness intelligence      1
# 73                               microservices      1
# 74                             usage profiling      1
# 75                            data exploration      1
# 76                                user testing      1
# 77                                user’s needs      1
# 78                                      design      1
# 79                         adaptive dashboards      1
# 80                                     sensors      1

# %%
# output_file('vbar.html')

p = figure(x_range=resultsKeywords['Term'].tolist(), plot_width=1250, toolbar_location=None, title="Keywords Counts")
p.vbar(x=resultsKeywords['Term'].tolist(), top=resultsKeywords['Count'].tolist(), width=0.3, color='#4BACC5')
p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = 9
p.xaxis.major_label_orientation = math.pi/2

show(p)
# Out:
#   <div class="bk-root" id="50b08e4b-012e-41ba-b02b-4a9e0bc0a329" data-root-id="93482"></div>

# %%
authors = df["Authors"].values
authors_list = []
for author in authors:
    [authors_list.append(x.strip()) for x in author.split(';')]
    
authors_list = [x for x in authors_list if x != '']

dfAuthors = pd.DataFrame(authors_list)
dfAuthors.columns = ['Name']

# %%
resultsAuthors = pd.DataFrame(dfAuthors['Name'].value_counts())
resultsAuthors.reset_index(inplace=True)
resultsAuthors.columns = ['Name', 'Count']

resultsAuthors.sort_values(['Count', 'Name'], ascending=[False, True], inplace=True)
resultsAuthors
# Out:
#                      Name  Count
# 2               Barros R.      2
# 1                 Belo O.      2
# 4              Correia H.      2
# 7    García-Peñalvo F. J.      2
# 6                Kintz M.      2
# 3            Rodrigues P.      2
# 5               Therón R.      2
# 0      Vázquez-Ingelmo A.      2
# 16               Arjun S.      1
# 39         Bederson B. B.      1
# 54          Bezerianos A.      1
# 72        Borges M. R. S.      1
# 68                Bose J.      1
# 55             Cardoso A.      1
# 26           Chowdhary P.      1
# 32              Collet P.      1
# 34          Danaisawat K.      1
# 12              Dantas V.      1
# 24               Elias M.      1
# 45            Elmqvist N.      1
# 28             Filonik D.      1
# 11                Foth M.      1
# 57             Furtado V.      1
# 70              George S.      1
# 25              Hruška T.      1
# 48                Huys C.      1
# 47               Hynek J.      1
# 41                Ines D.      1
# 52            Janssens O.      1
# 22          Jean-Marie G.      1
# 13                  Ji M.      1
# 50            Karstens E.      1
# 8         Khunkornsiri T.      1
# 56         Kochanowski M.      1
# 60             Koetter F.      1
# 73              Kukolj S.      1
# 30               Kumar K.      1
# 23              Lavoue E.      1
# 65               Logre I.      1
# 58              Madeth M.      1
# 29             Magnoni L.      1
# 10         Majstorović B.      1
# 40               Mayer B.      1
# 14       McGuinness D. L.      1
# 42             Medland R.      1
# 51              Michel C.      1
# 69             Mihaila G.      1
# 59           Miotto G. L.      1
# 61              Mosser S.      1
# 44       Nascimento B. S.      1
# 66          Noonpakdee W.      1
# 38            Palpanas T.      1
# 21         Pastushenko O.      1
# 31             Petasis G.      1
# 62          Phothichai A.      1
# 46               Pinel F.      1
# 43            Pinheiro P.      1
# 17         Radovanović S.      1
# 64         Rittenbruch M.      1
# 35             Riveill M.      1
# 27              Santos H.      1
# 67           Sebastien I.      1
# 18               Serge G.      1
# 33           Sloper J. E.      1
# 15             Soni S. K.      1
# 37         Sousa Pinto J.      1
# 19       Triantafillou A.      1
# 53          Van Hoecke S.      1
# 36            Verborgh R.      1
# 71  Vieira Teixeira C. J.      1
# 63         Vivacqua A. S.      1
# 9            Weinreich R.      1
# 20           Yalcin M. A.      1
# 49         de Walle R. V.      1

# %%
p = figure(x_range=resultsAuthors['Name'].tolist(), plot_width=990, toolbar_location=None, title="Authors Counts")
p.vbar(x=resultsAuthors['Name'].tolist(), top=resultsAuthors['Count'].tolist(), width=0.3, color='#4BACC5')
p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = 4
p.xaxis.major_label_orientation = math.pi/2

show(p)
# Out:
#   <div class="bk-root" id="d7f0a658-ee1a-4f27-aa1d-96604086e0f5" data-root-id="94698"></div>

# %%
resultsYears = pd.DataFrame(df['Year'].value_counts())
resultsYears.reset_index(inplace=True)
resultsYears.columns = ['Year', 'Count']
resultsYears.sort_values(['Year', 'Count'], ascending=[False, False], inplace=True)
resultsYears
# Out:
#    Year  Count
# 0  2018      8
# 1  2017      6
# 3  2016      3
# 2  2014      3
# 5  2013      1
# 6  2012      1
# 4  2011      2
# 7  2007      1

# %%
x = resultsYears['Year'].astype('str').tolist() + ['2015', '2010', '2009', '2008']
x.sort()
p = figure(x_range=x, plot_width=600, plot_height=400, toolbar_location=None, title="Papers per year")
p.vbar(x=resultsYears['Year'].astype('str').tolist(), top=resultsYears['Count'].astype('int').tolist(), color='#4BACC5', width=0.9)
p.xgrid.grid_line_color = None
p.yaxis[0].ticker.desired_num_ticks = 10
p.y_range.start = 0

show(p)
# Out:
#   <div class="bk-root" id="a5758c32-19e8-46a1-9ab2-28f8c1389abb" data-root-id="95922"></div>

# %%
resultsType = pd.DataFrame(df['Type of publication (Journal, Book, Conference proceedings, etc)'].value_counts())
resultsType.reset_index(inplace=True)
resultsType.columns = ['Type', 'Count']
resultsType.sort_values(['Type', 'Count'], ascending=[False, False], inplace=True)
resultsType
# Out:
#                Type  Count
# 0  Conference Paper     21
# 1           Article      4

# %%
p = figure(x_range=resultsType['Type'].tolist(), plot_width=600, plot_height=600, title="Publication type")
p.vbar(x=resultsType['Type'].tolist(), top=resultsType['Count'].tolist(), width=0.9, color='#4BACC5')
p.xgrid.grid_line_color = None
p.yaxis[0].ticker.desired_num_ticks = 10
p.y_range.start = 0

show(p)
# Out:
#   <div class="bk-root" id="1d7343fd-9606-4025-80de-ee60bcde828d" data-root-id="97155"></div>

# %%
variability = df["Variability factors (factors that affect the dashboard composition)"].values
variability_list = []
for v in variability:
    [variability_list.append(x.strip().lower().capitalize()) for x in v.split(',')]
    
variability_list = [x for x in variability_list if x != '']

dfVariability = pd.DataFrame(variability_list)
dfVariability.columns = ['Name']

resultsVariability = pd.DataFrame(dfVariability['Name'].value_counts())
resultsVariability.reset_index(inplace=True)
resultsVariability.columns = ['Name', 'Count']
resultsVariability.sort_values(['Name', 'Count'], ascending=[True, False], inplace=True)
resultsVariability
# Out:
#                                Name  Count
# 9                 Analysis scenario      1
# 1                  Business process      3
# 6                      Data sources      2
# 2                    Data structure      3
# 5                             Goals      2
# 4                        Guidelines      2
# 3                    Usage profiles      2
# 7                    User abilities      1
# 10  User description data structure      1
# 0                  User preferences     16
# 8                         User role      1

# %%
p = figure(x_range=resultsVariability['Name'].astype('str').tolist(), plot_width=800, plot_height=500, title="Variability factors")
p.vbar(x=resultsVariability['Name'].astype('str').tolist(), top=resultsVariability['Count'].astype('int').tolist(), width=0.5, color='#4BACC5')
p.xgrid.grid_line_color = None
p.xaxis.major_label_orientation = math.pi/3.8
p.yaxis[0].ticker.desired_num_ticks = 12
p.y_range.start = 0

show(p)
# Out:
#   <div class="bk-root" id="b530157c-86bd-448e-99f9-37f8895fb44e" data-root-id="98396"></div>

# %%
resultsDomain = pd.DataFrame(df['Application domain'].value_counts())
resultsDomain.reset_index(inplace=True)
resultsDomain.columns = ['Name', 'Count']
resultsDomain.sort_values(['Name', 'Count'], ascending=[True, False], inplace=True)
resultsDomain
# Out:
#                         Name  Count
# 0                         BI      8
# 11       Disaster situations      1
# 6                  Economics      1
# 9       Emergency management      1
# 13         Energy monitoring      1
# 8                    Generic      1
# 7       Interface evaluation      1
# 1                        IoT      2
# 4         Learning Analytics      2
# 10  Microservices monitoring      1
# 5                    Physics      1
# 12         Sensor monitoring      1
# 2        Services monitoring      2
# 3            Social sciences      2

# %%
p = figure(x_range=resultsDomain['Name'].astype('str').tolist(), plot_width=600, plot_height=500, title="Application domain")
p.vbar(x=resultsDomain['Name'].astype('str').tolist(), top=resultsDomain['Count'].astype('int').tolist(), width=0.5, color='#4BACC5')
p.xgrid.grid_line_color = None
p.xaxis.major_label_orientation = math.pi/4
p.xaxis.major_label_text_font_size = "9pt"
p.yaxis[0].ticker.desired_num_ticks = 12
p.y_range.start = 0

show(p)
# Out:
#   <div class="bk-root" id="4e2b6d39-106c-4859-988b-08fe84d08166" data-root-id="99645"></div>

# %%
method = df["Method"].values
method_list = []
for m in method:
    [method_list.append(x.strip().lower().capitalize()) for x in m.split(',')]
    
method_list = [x for x in method_list if x != '']

dfMethod = pd.DataFrame(method_list)
dfMethod.columns = ['Name']

resultsMethod = pd.DataFrame(dfMethod['Name'].value_counts())
resultsMethod.reset_index(inplace=True)
resultsMethod.columns = ['Name', 'Count']
resultsMethod.sort_values(['Name', 'Count'], ascending=[True, False], inplace=True)
resultsMethod
# Out:
#                            Name  Count
# 3                        Agents      3
# 2           Configuration files      3
# 0          Configuration wizard      8
# 8   Context-sensitive generator      1
# 7      Inclusive user modelling      1
# 9            Indicator ontology      1
# 11             Knowledge graphs      1
# 5                  Model driven      3
# 6         Pre-defined templates      2
# 10            Semantic reasoner      1
# 4                           Spl      3
# 1                Visual mapping      4

# %%
p = figure(x_range=resultsMethod['Name'].astype('str').tolist(), plot_width=600, plot_height=500, title="Variability methods")
p.vbar(x=resultsMethod['Name'].astype('str').tolist(), top=resultsMethod['Count'].astype('int').tolist(), width=0.5, color='#4BACC5')
p.xgrid.grid_line_color = None
p.xaxis.major_label_orientation = math.pi/4
p.yaxis[0].ticker.desired_num_ticks = 12
p.y_range.start = 0

show(p)
# Out:
#   <div class="bk-root" id="8ad16445-4fb1-460f-96e1-20738f00193d" data-root-id="100902"></div>

# %%
target = df["Target of the variability process"].values
target_list = []
for t in target:
    [target_list.append(x.strip().lower().capitalize()) for x in t.split(',')]
    
target_list = [x for x in target_list if x != '']

dfTarget = pd.DataFrame(target_list)
dfTarget.columns = ['Name']

resultsTarget = pd.DataFrame(dfTarget['Name'].value_counts())
resultsTarget.reset_index(inplace=True)
resultsTarget.columns = ['Name', 'Count']
resultsTarget.sort_values(['Name', 'Count'], ascending=[True, False], inplace=True)
resultsTarget
# Out:
#                  Name  Count
# 0      Displayed data     24
# 3     Functionalities      2
# 4         Interaction      2
# 2              Layout     22
# 5       Visual design      2
# 1  Visualization type     23

# %%
p = figure(x_range=resultsTarget['Name'].astype('str').tolist(), plot_width=600, plot_height=500, title="Target of the variability process")
p.vbar(x=resultsTarget['Name'].astype('str').tolist(), top=resultsTarget['Count'].astype('int').tolist(), width=0.5, color='#4BACC5')
p.xgrid.grid_line_color = None
p.xaxis.major_label_orientation = math.pi/4
p.xaxis.major_label_text_font_size = "10pt"
p.yaxis[0].ticker.desired_num_ticks = 12
p.y_range.start = 0

show(p)
# Out:
#   <div class="bk-root" id="901635b6-f304-4ee5-ab77-3e3b55d43049" data-root-id="102167"></div>

# %%
stage = df["Stage at which the variation / customization / personalization is performed"].values
stage_list = []
for s in stage:
    [stage_list.append(x.strip().lower().capitalize()) for x in s.split(',')]
    
stage_list = [x for x in stage_list if x != '']

dfStage = pd.DataFrame(stage_list)
dfStage.columns = ['Name']

resultsStage = pd.DataFrame(dfStage['Name'].value_counts())
resultsStage.reset_index(inplace=True)
resultsStage.columns = ['Name', 'Count']
resultsStage.sort_values(['Name', 'Count'], ascending=[True, False], inplace=True)
resultsStage
# Out:
#                  Name  Count
# 3        Compile-time      1
# 0   Pre-configuration     10
# 2            Run-time      7
# 1  User-configuration      8

# %%
p = figure(x_range=resultsStage['Name'].astype('str').tolist(), plot_width=600, plot_height=500, title="Stage at which the variability process is applied")
p.vbar(x=resultsStage['Name'].astype('str').tolist(), top=resultsStage['Count'].astype('int').tolist(), width=0.5, color='#4BACC5')
p.xgrid.grid_line_color = None
p.xaxis.major_label_orientation = math.pi/4
p.xaxis.major_label_text_font_size = "12pt"
p.yaxis[0].ticker.desired_num_ticks = 12
p.y_range.start = 0

export_png(p, filename="Figure 4.png")
show(p)
# Out:
#   <div class="bk-root" id="2d71d3a1-2998-4d35-b66a-09b1997d867c" data-root-id="103440"></div>

# %%
resultsTest = pd.DataFrame(df['Tested in real-world scenario?'].value_counts())
resultsTest.reset_index(inplace=True)
resultsTest.columns = ['Name', 'Count']
resultsTest.sort_values(['Name', 'Count'], ascending=[True, False], inplace=True)
resultsTest
# Out:
#       Name  Count
# 1       No      7
# 2  Partial      5
# 0      Yes     13

# %%
p = figure(x_range=resultsTest['Name'].astype('str').tolist(), plot_width=600, plot_height=500, title="Solution tested in real-world scenario?")
p.vbar(x=resultsTest['Name'].astype('str').tolist(), top=resultsTest['Count'].astype('int').tolist(), width=0.5, color='#4BACC5')
p.xgrid.grid_line_color = None
p.xaxis.major_label_orientation = math.pi/4
p.xaxis.major_label_text_font_size = "12pt"
p.yaxis[0].ticker.desired_num_ticks = 12
p.y_range.start = 0

show(p)
# Out:
#   <div class="bk-root" id="57bbbda6-125c-467e-a584-c3344467bf90" data-root-id="104794"></div>

# %%
resultsClassification = pd.DataFrame(df['First level classification'].value_counts())
resultsClassification.reset_index(inplace=True)
resultsClassification.columns = ['Name', 'Count']
resultsClassification.sort_values(['Name', 'Count'], ascending=[True, False], inplace=True)
resultsClassification
# Out:
#                              Name  Count
# 2                        Adaptive      4
# 0                    Customizable     11
# 3  Customizable w/ system support      3
# 4                          Hybrid      2
# 1                    Personalized      5

# %%
p = figure(x_range=resultsClassification['Name'].astype('str').tolist(), plot_width=600, plot_height=500, title="Solutions' classification")
p.vbar(x=resultsClassification['Name'].astype('str').tolist(), top=resultsClassification['Count'].astype('int').tolist(), width=0.5, color='#4BACC5')
p.xgrid.grid_line_color = None
p.xaxis.major_label_orientation = math.pi/4
p.yaxis[0].ticker.desired_num_ticks = 12
p.y_range.start = 0

show(p)
# Out:
#   <div class="bk-root" id="0dd0b118-c27d-48eb-aa71-3cf863f7e048" data-root-id="106083"></div>
